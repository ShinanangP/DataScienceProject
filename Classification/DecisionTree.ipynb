# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import label encoder 
from sklearn import preprocessing 
# Import model
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Load Dataset

# %%
os.getcwd()
# Out:
# 'c:\\Users\\ASUS\\Documents\\Work\\DataScienceProject\\Classification'

# %%
data_df = pd.read_csv("../Data/MBA.csv")
data_df
# Out:
#       application_id  gender  international   gpa       major      race  \
# 0                  1  Female          False  3.30    Business     Asian
# 1                  2    Male          False  3.28  Humanities     Black
# 2                  3  Female           True  3.30    Business       NaN
# 3                  4    Male          False  3.47        STEM     Black
# 4                  5    Male          False  3.35        STEM  Hispanic
# ...              ...     ...            ...   ...         ...       ...
# 6189            6190    Male          False  3.49    Business     White
# 6190            6191    Male          False  3.18        STEM     Black
# 6191            6192  Female           True  3.22    Business       NaN
# 6192            6193    Male           True  3.36    Business       NaN
# 6193            6194    Male          False  3.23        STEM  Hispanic
#
#        gmat  work_exp          work_industry admission
# ...

# %%
for column in data_df.columns[1:]:
    print("Column: {}".format(column))
    print(data_df[column].unique())
# Out:
# Column: gender
# ['Female' 'Male']
# Column: international
# [False  True]
# Column: gpa
# [3.3  3.28 3.47 3.35 3.18 2.93 3.02 3.24 3.27 3.05 2.85 3.39 3.03 3.32
#  3.23 3.13 3.09 3.46 3.64 3.42 3.4  3.26 2.99 3.08 3.65 3.04 3.19 3.33
#  3.53 3.5  3.22 3.16 3.45 3.12 3.41 3.38 3.43 2.96 3.44 3.01 3.   3.36
#  3.31 3.07 3.49 3.34 2.89 3.2  3.17 3.1  3.52 3.15 3.21 3.48 3.14 2.97
#  3.11 3.29 3.25 3.51 3.06 2.95 3.37 3.55 3.54 3.6  3.61 3.71 3.77 3.58
#  2.98 3.56 3.69 2.79 2.87 2.88 3.63 2.9  3.74 2.91 2.92 2.78 3.57 3.66
#  2.81 3.59 2.82 3.62 2.73 3.68 2.84 2.83 2.86 3.67 2.94 2.72 2.8  3.76
#  3.7  3.73 2.65]
# Column: major
# ['Business' 'Humanities' 'STEM']
# Column: race
# ['Asian' 'Black' nan 'Hispanic' 'White' 'Other']
# Column: gmat
# [620. 680. 710. 690. 590. 610. 630. 580. 640. 600. 700. 670. 760. 730.
#  570. 650. 720. 740. 660. 780. 750. 770.]
# Column: work_exp
# [3. 5. 6. 2. 4. 8. 7. 9. 1.]
# Column: work_industry
# ...

# %%
# show column that contains NaN
print(data_df.columns[data_df.isna().any()].tolist())
data_df.isna().any()
# Out:
# ['race', 'admission']
# application_id    False
# gender            False
# international     False
# gpa               False
# major             False
# race               True
# gmat              False
# work_exp          False
# work_industry     False
# admission          True
# dtype: bool

# %%
# select rows that not contains NaN
new_data_df = data_df[data_df.isna().any(axis = 1) == False]
new_data_df
# Out:
#       application_id  gender  international   gpa       major      race  \
# 0                  1  Female          False  3.30    Business     Asian
# 6                  7  Female          False  2.93        STEM     Other
# 12                13  Female          False  3.24  Humanities  Hispanic
# 14                15  Female          False  3.03        STEM     White
# 16                17  Female          False  3.32    Business     Asian
# ...              ...     ...            ...   ...         ...       ...
# 6150            6151  Female          False  3.46    Business     Asian
# 6152            6153  Female          False  3.31    Business     Black
# 6168            6169  Female          False  3.21        STEM     White
# 6175            6176  Female          False  3.38  Humanities  Hispanic
# 6177            6178    Male          False  3.35  Humanities  Hispanic
#
#        gmat  work_exp       work_industry admission
# ...

# %%
pd.crosstab(new_data_df["admission"], new_data_df["gender"], margins = True)
# Out:
# gender     Female  Male  All
# admission
# Admit         311   311  622
# Waitlist       35    35   70
# All           346   346  692

# %%
# label_encoder = preprocessing.LabelEncoder() 
  
# # Encode labels in column 'species'. 
# y = label_encoder.fit_transform(new_data_df["admission"])

# # Show dict
# print(dict(zip(label_encoder.classes_, range(len(label_encoder.classes_)))))
